# %%
import cv2

from algorithm_creation import match_features

# %matplotlib inline

# %% [markdown]
# ## Extract images

# %%
train_photo = cv2.imread("images/train.jpg")
query_photo = cv2.imread("images/query.jpg")

# %% [markdown]
# ## Find mathing features

# %%
match_features(train_photo, query_photo)
# Out:
# Raw matches (knn): 10001
